# %% [markdown]
# # Exploração dos Dados do Enem 2021
#
# ## Antes de mais nada precisamos definir com quais bibliotecas iremos trabalhar na Exploração dos dados do enem 2021.
#
# ## Vamos importar a biblioteca Pandas e numpy, pois vamos manipular dados armazenados em planilhas, pois assim conseguiremos explorar, limpar e processar os dados existentes no dataset.

# %% [markdown]
# Fonte dos dados: https://www.gov.br/inep/pt-br/acesso-a-informacao/dados-abertos/microdados/enem

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
#  ## O pandas irá ler o arquivo csv com o método pd.read_csv( )

# %%
microdados_enem = pd.read_csv("MICRODADOS_ENEM_2021.csv", encoding="ISO -8859-1", sep = ';')

# %% [markdown]
# ## Utilizar o head() para visualiar as 5 primeira linhas do dataset. Por padrão o metodo ele trás as 5 primeira, mas pode escolher quantas linhas você deseja visualizar.

# %%
microdados_enem.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210053865474    2021                5       F                1
# 1  210052384164    2021               12       M                1
# 2  210052589243    2021               13       F                3
# 3  210052128335    2021                3       M                1
# 4  210051353021    2021                2       F                1
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            1                 1                1                3          1
# 1            1                 1                1               11          1
# 2            1                 1                1               15          1
# 3            3                 1                2                0          2
# 4            3                 1                2                0          2
#
#    ...  Q016  Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  Q025
# ...

# %% [markdown]
# ## Outra forma de visualizar o DataFrame é chamando somente pelo nome atribuido ao DataFrame, assim temos uma visão dos 5 primeiros dados e também os 5 últimos além de o número total de linhas e colunas do dataframe.

# %%
microdados_enem
# Out:
#          NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0        210053865474    2021                5       F                1
# 1        210052384164    2021               12       M                1
# 2        210052589243    2021               13       F                3
# 3        210052128335    2021                3       M                1
# 4        210051353021    2021                2       F                1
# ...               ...     ...              ...     ...              ...
# 3389827  210053249138    2021                7       F                1
# 3389828  210053776013    2021                7       F                1
# 3389829  210052441508    2021               13       F                1
# 3389830  210051139675    2021                7       F                1
# 3389831  210052410399    2021               12       F                2
#
#          TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# ...

# %% [markdown]
# ### No final da tabela podemos verificar que o dataframe possui 3.389.832( Três milhores, trezentos e oitenta e nove mil e oitocentos e trinta e duas) linhas e 76(setenta e seis) colunas.
#
# ### Poderiamos utilizar o método shape() para conhecer o número de linhas e colunas do df.

# %%
print('O dataframe possui {} linhas e {} colunas'.format(microdados_enem.shape[0], microdados_enem.shape[1]))
# Out:
# O dataframe possui 3389832 linhas e 76 colunas

# %%
microdados_enem.shape
# Out:
# (3389832, 76)

# %% [markdown]
# # Vamos visualizar todas as colunas existentes no DataFrame utilizando os metodos columns.values

# %%
# Vamos visualizar todas as colunas existentes no DataFrame
microdados_enem.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
#        'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
#        'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
#        'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
#        'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
#        'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
#        'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
#        'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
#        'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
#        'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA',
#        'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC',
#        'TX_GABARITO_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
#        'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
# ...

# %%
colunas_selecionas = ['NU_INSCRICAO','NU_ANO','TP_SEXO','TP_FAIXA_ETARIA',
       'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE',
       'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
       'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
       'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
       'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
       'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
       'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
       'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
       'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
       'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
       'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA',
       'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC',
       'TX_GABARITO_MT', 'TP_STATUS_REDACAO','NU_NOTA_REDACAO','Q001', 'Q002']

# %%
microdados_enem_selecionado = microdados_enem.filter(items=colunas_selecionas)
microdados_enem_selecionado
# Out:
#          NU_INSCRICAO  NU_ANO TP_SEXO  TP_FAIXA_ETARIA  TP_ESTADO_CIVIL  \
# 0        210053865474    2021       F                5                1
# 1        210052384164    2021       M               12                1
# 2        210052589243    2021       F               13                3
# 3        210052128335    2021       M                3                1
# 4        210051353021    2021       F                2                1
# ...               ...     ...     ...              ...              ...
# 3389827  210053249138    2021       F                7                1
# 3389828  210053776013    2021       F                7                1
# 3389829  210052441508    2021       F               13                1
# 3389830  210051139675    2021       F                7                1
# 3389831  210052410399    2021       F               12                2
#
#          TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# ...

# %% [markdown]
# ## Iremos fazer algumas perguntas para o Dataset

# %% [markdown]
# ## 1) Qual a distribuição de sexo declarado no Enem?

# %%
dist_sexo = microdados_enem_selecionado['TP_SEXO']
dist_sexo.value_counts()
# Out:
# F    2090526
# M    1299306
# Name: TP_SEXO, dtype: int64

# %%
percentual=dist_sexo.value_counts(normalize = True)*100
percentual
# Out:
# F    61.67049
# M    38.32951
# Name: TP_SEXO, dtype: float64

# %%
dist_freq_qualitativas = pd.DataFrame({'Frequência': dist_sexo.value_counts(), 'Porcentagem (%)': dist_sexo.value_counts(normalize = True)*100})
dist_freq_qualitativas.rename(index = {"M": 'Masculino', "F": 'Feminino'}, inplace = True)
dist_freq_qualitativas.rename_axis('Sexo', axis = 'columns', inplace =True)
dist_freq_qualitativas
# Out:
# Sexo       Frequência  Porcentagem (%)
# Feminino      2090526         61.67049
# Masculino     1299306         38.32951

# %% [markdown]
# Cerca de 62% dos candidatos são do sexo feminino e 38% do sexo masculino.
#
# Segundo um levamanento feito pelo Instituto Semesp, 57% dos estudantes matriculados nas instituições de ensino superiores são do sexo feminino.(https://agenciabrasil.ebc.com.br/educacao/noticia/2020-05/mapa-do-ensino-superior-aponta-para-maioria-feminina-e-branca)
# Um dado que era de se esperar, pois a quantidade de candidatos que prestam o Vestibular do Enem são do sexo feminino.

# %% [markdown]
# ##  2) Qual relação de distribuição de candidatos por sexo e faixa etária?

# %%
dist_faixa_etaria = microdados_enem_selecionado['TP_FAIXA_ETARIA'].map({1:'Menor de 17 anos', 2:'17 anos', 3:'18 anos', 4:'19 anos',5:'20 anos',
6:'21 anos', 7:'22 anos', 8:'23 anos', 9:'24 anos', 10:'25 anos', 11:'Entre 26 e 30 anos',
12:'Entre 31 e 35 anos', 13:'Entre 36 e 40 anos', 14:'Entre 41 e 45 anos', 15:'Entre 46 e 50 anos',
16:'Entre 51 e 55 anos', 17:'Entre 56 e 60 anos', 18:'Entre 61 e 65 anos',19:'Entre 66 e 70 anos',
20:'Maior de 70 anos'}).value_counts()
dist_faixa_etaria
# Out:
# 18 anos               699365
# 17 anos               620784
# 19 anos               394689
# Menor de 17 anos      274318
# 20 anos               250690
# Entre 26 e 30 anos    227574
# 21 anos               177086
# 22 anos               132052
# Entre 31 e 35 anos    130746
# 23 anos               100580
# Entre 36 e 40 anos     93073
# 24 anos                85742
# 25 anos                71199
# Entre 41 e 45 anos     58754
# Entre 46 e 50 anos     35808
# Entre 51 e 55 anos     20564
# Entre 56 e 60 anos     10804
# Entre 61 e 65 anos      4102
# Entre 66 e 70 anos      1342
# Maior de 70 anos         560
# Name: TP_FAIXA_ETARIA, dtype: int64

# %%
percentual_faixa_etaria = microdados_enem_selecionado['TP_FAIXA_ETARIA'].map({1:'Menor de 17 anos', 2:'17 anos', 3:'18 anos', 4:'19 anos',5:'20 anos',
6:'21 anos', 7:'22 anos', 8:'23 anos', 9:'24 anos', 10:'25 anos', 11:'Entre 26 e 30 anos',
12:'Entre 31 e 35 anos', 13:'Entre 36 e 40 anos', 14:'Entre 41 e 45 anos', 15:'Entre 46 e 50 anos',
16:'Entre 51 e 55 anos', 17:'Entre 56 e 60 anos', 18:'Entre 61 e 65 anos',19:'Entre 66 e 70 anos',
20:'Maior de 70 anos'}).value_counts(normalize = True)*100
percentual_faixa_etaria
# Out:
# 18 anos               20.631258
# 17 anos               18.313120
# 19 anos               11.643320
# Menor de 17 anos       8.092377
# 20 anos                7.395352
# Entre 26 e 30 anos     6.713430
# 21 anos                5.224035
# 22 anos                3.895532
# Entre 31 e 35 anos     3.857005
# 23 anos                2.967109
# Entre 36 e 40 anos     2.745652
# 24 anos                2.529388
# 25 anos                2.100370
# Entre 41 e 45 anos     1.733242
# Entre 46 e 50 anos     1.056336
# Entre 51 e 55 anos     0.606638
# Entre 56 e 60 anos     0.318718
# Entre 61 e 65 anos     0.121009
# Entre 66 e 70 anos     0.039589
# Maior de 70 anos       0.016520
# Name: TP_FAIXA_ETARIA, dtype: float64

# %%
dist_frequencia_faixaetaria = pd.DataFrame({"Frequência": dist_faixa_etaria , "Porcentagem (%)": percentual_faixa_etaria})
dist_frequencia_faixaetaria
# Out:
#                     Frequência  Porcentagem (%)
# 18 anos                 699365        20.631258
# 17 anos                 620784        18.313120
# 19 anos                 394689        11.643320
# Menor de 17 anos        274318         8.092377
# 20 anos                 250690         7.395352
# Entre 26 e 30 anos      227574         6.713430
# 21 anos                 177086         5.224035
# 22 anos                 132052         3.895532
# Entre 31 e 35 anos      130746         3.857005
# 23 anos                 100580         2.967109
# Entre 36 e 40 anos       93073         2.745652
# 24 anos                  85742         2.529388
# 25 anos                  71199         2.100370
# Entre 41 e 45 anos       58754         1.733242
# Entre 46 e 50 anos       35808         1.056336
# Entre 51 e 55 anos       20564         0.606638
# Entre 56 e 60 anos       10804         0.318718
# Entre 61 e 65 anos        4102         0.121009
# Entre 66 e 70 anos        1342         0.039589
# ...

# %%
nota_redacao_por_sexo = ['TP_SEXO','NU_NOTA_REDACAO']

# %%
microdados_enem_selecionado_sexo = microdados_enem.filter(items = nota_redacao_por_sexo)

# %%
microdados_enem_selecionado_sexo.head()
# Out:
#   TP_SEXO  NU_NOTA_REDACAO
# 0       F            760.0
# 1       M            560.0
# 2       F              NaN
# 3       M            780.0
# 4       F            780.0

# %%
microdados_enem_selecionado_sexo = microdados_enem_selecionado_sexo.dropna()
microdados_enem_selecionado_sexo.head()
# Out:
#   TP_SEXO  NU_NOTA_REDACAO
# 0       F            760.0
# 1       M            560.0
# 3       M            780.0
# 4       F            780.0
# 6       F            480.0

# %%
microdados_enem_selecionado_sexo.groupby('TP_SEXO').count()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F                1470366
# M                 908013

# %%
microdados_enem_selecionado_sexo.groupby('TP_SEXO').max()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F                 1000.0
# M                 1000.0

# %%
microdados_enem_selecionado_sexo.groupby('TP_SEXO').min()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F                    0.0
# M                    0.0

# %%
microdados_enem_selecionado_sexo[microdados_enem_selecionado_sexo.NU_NOTA_REDACAO > 0].groupby('TP_SEXO').min()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F                   40.0
# M                   40.0

# %%
microdados_enem_selecionado_sexo.groupby('TP_SEXO').mean()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F             624.351338
# M             595.929464

# %%
microdados_enem_selecionado_sexo.groupby('TP_SEXO').median()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F                  620.0
# M                  600.0

# %%
microdados_enem_selecionado_sexo.groupby('TP_SEXO').describe()
# Out:
#         NU_NOTA_REDACAO                                                    \
#                   count        mean         std  min    25%    50%    75%
# TP_SEXO
# F             1470366.0  624.351338  189.050757  0.0  520.0  620.0  760.0
# M              908013.0  595.929464  192.081911  0.0  520.0  600.0  720.0
#
#
#             max
# TP_SEXO
# F        1000.0
# M        1000.0

# %%
sns.set_style("whitegrid")
sns.boxplot(data = microdados_enem_selecionado_sexo, x = 'TP_SEXO', y = 'NU_NOTA_REDACAO', palette="deep" )
plt.show()

# %%
#definindo um dicionario para visualizar melhor o resultado

dicionarioq01q02 = {'A': 'Nunca estudou',
'B': 'Não completou a 4ª série/5º ano do Ensino Fundamental',
'C': 'Completou a 4ª série/5º ano, mas não completou a 8ª série/9º ano do Ensino Fundamental',
'D': 'Completou a 8ª série/9º ano do Ensino Fundamental, mas não completou o Ensino Médio',
'E': 'Completou o Ensino Médio, mas não completou a Faculdade',
'F': 'Completou a Faculdade, mas não completou a Pós-graduação',
'G': 'Completou a Pós-graduação',
'H':'Não sei'}

# %%
colunasselecionadas = ['NU_INSCRICAO','NU_NOTA_MT','NU_NOTA_REDACAO','Q001', 'Q002']

# %%
microdadosenemselecionado = microdados_enem_selecionado.filter(items = colunasselecionadas)

# %%
microdadosenemselecionado
# Out:
#          NU_INSCRICAO  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002
# 0        210053865474         NaN            760.0    F    F
# 1        210052384164       461.5            560.0    B    B
# 2        210052589243         NaN              NaN    B    C
# 3        210052128335       659.5            780.0    B    B
# 4        210051353021       582.6            780.0    D    E
# ...               ...         ...              ...  ...  ...
# 3389827  210053249138         NaN              NaN    B    B
# 3389828  210053776013         NaN              NaN    E    E
# 3389829  210052441508         NaN              NaN    B    C
# 3389830  210051139675       706.4            660.0    E    D
# 3389831  210052410399         NaN              NaN  NaN  NaN
#
# [3389832 rows x 5 columns]

# %%
microdadosenemselecionado = microdadosenemselecionado.dropna()
microdadosenemselecionado.head()
# Out:
#    NU_INSCRICAO  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002
# 1  210052384164       461.5            560.0    B    B
# 3  210052128335       659.5            780.0    B    B
# 4  210051353021       582.6            780.0    D    E
# 8  210053417016       493.4            520.0    B    B
# 9  210051128744       413.3            380.0    D    D

# %%
microdadosenemselecionado['NO_Q001'] = [dicionarioq01q02[resp] for resp in microdadosenemselecionado.Q001]
# Out:
# C:\Users\David\AppData\Local\Temp/ipykernel_5372/4054428148.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   microdadosenemselecionado['NO_Q001'] = [dicionarioq01q02[resp] for resp in microdadosenemselecionado.Q001]

# %%
microdadosenemselecionado.Q001
# Out:
# 1          B
# 3          B
# 4          D
# 8          B
# 9          D
#           ..
# 3389793    B
# 3389807    H
# 3389814    E
# 3389815    C
# 3389830    E
# Name: Q001, Length: 2238106, dtype: object

# %%
microdadosenemselecionado.head()
# Out:
#    NU_INSCRICAO  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002  \
# 1  210052384164       461.5            560.0    B    B
# 3  210052128335       659.5            780.0    B    B
# 4  210051353021       582.6            780.0    D    E
# 8  210053417016       493.4            520.0    B    B
# 9  210051128744       413.3            380.0    D    D
#
#                                              NO_Q001
# 1  Não completou a 4ª série/5º ano do Ensino Fund...
# 3  Não completou a 4ª série/5º ano do Ensino Fund...
# 4  Completou a 8ª série/9º ano do Ensino Fundamen...
# 8  Não completou a 4ª série/5º ano do Ensino Fund...
# 9  Completou a 8ª série/9º ano do Ensino Fundamen...

# %%
microdadosenemselecionado['NO_Q002'] = [dicionarioq01q02[resp] for resp in microdadosenemselecionado.Q002]
# Out:
# C:\Users\David\AppData\Local\Temp/ipykernel_5372/3364845719.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   microdadosenemselecionado['NO_Q002'] = [dicionarioq01q02[resp] for resp in microdadosenemselecionado.Q002]

# %%
microdadosenemselecionado.Q002
# Out:
# 1          B
# 3          B
# 4          E
# 8          B
# 9          D
#           ..
# 3389793    B
# 3389807    C
# 3389814    E
# 3389815    H
# 3389830    D
# Name: Q002, Length: 2238106, dtype: object

# %%
microdadosenemselecionado.head()
# Out:
#    NU_INSCRICAO  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002  \
# 1  210052384164       461.5            560.0    B    B
# 3  210052128335       659.5            780.0    B    B
# 4  210051353021       582.6            780.0    D    E
# 8  210053417016       493.4            520.0    B    B
# 9  210051128744       413.3            380.0    D    D
#
#                                              NO_Q001  \
# 1  Não completou a 4ª série/5º ano do Ensino Fund...
# 3  Não completou a 4ª série/5º ano do Ensino Fund...
# 4  Completou a 8ª série/9º ano do Ensino Fundamen...
# 8  Não completou a 4ª série/5º ano do Ensino Fund...
# 9  Completou a 8ª série/9º ano do Ensino Fundamen...
#
#                                              NO_Q002
# 1  Não completou a 4ª série/5º ano do Ensino Fund...
# 3  Não completou a 4ª série/5º ano do Ensino Fund...
# 4  Completou o Ensino Médio, mas não completou a ...
# 8  Não completou a 4ª série/5º ano do Ensino Fund...
# ...

# %%
#distribuição de nível de escolaridade do Pai

microdadosenemselecionado.filter(items=['NU_INSCRICAO', 'NO_Q001']).groupby('NO_Q001').count().sort_values(by='NU_INSCRICAO', ascending=False)
# Out:
#                                                     NU_INSCRICAO
# NO_Q001
# Completou o Ensino Médio, mas não completou a F...        681530
# Não completou a 4ª série/5º ano do Ensino Funda...        349980
# Completou a 4ª série/5º ano, mas não completou ...        281447
# Completou a Faculdade, mas não completou a Pós-...        246549
# Completou a 8ª série/9º ano do Ensino Fundament...        245630
# Completou a Pós-graduação                                 183606
# Não sei                                                   172965
# Nunca estudou                                              76399

# %%
#distribuição de nível de escolaridade do Mae
microdadosenemselecionado.filter(items=['NU_INSCRICAO', 'NO_Q002']).groupby('NO_Q002').count().sort_values(by='NU_INSCRICAO', ascending=False)
# Out:
#                                                     NU_INSCRICAO
# NO_Q002
# Completou o Ensino Médio, mas não completou a F...        795005
# Completou a Faculdade, mas não completou a Pós-...        321187
# Completou a Pós-graduação                                 309702
# Completou a 8ª série/9º ano do Ensino Fundament...        245533
# Não completou a 4ª série/5º ano do Ensino Funda...        243449
# Completou a 4ª série/5º ano, mas não completou ...        226251
# Não sei                                                    48908
# Nunca estudou                                              48071

# %%
# Desempenho em Matemática em relação à escolidade do PAI
microdadosenemselecionado.filter(items=['NU_NOTA_MT', 'NO_Q001']).groupby('NO_Q001').mean().sort_values(by='NU_NOTA_MT', ascending=False)
# Out:
#                                                     NU_NOTA_MT
# NO_Q001
# Completou a Pós-graduação                           613.461090
# Completou a Faculdade, mas não completou a Pós-...  597.511863
# Completou o Ensino Médio, mas não completou a F...  543.113614
# Completou a 8ª série/9º ano do Ensino Fundament...  521.973493
# Completou a 4ª série/5º ano, mas não completou ...  511.070163
# Não sei                                             504.740075
# Não completou a 4ª série/5º ano do Ensino Funda...  492.429393
# Nunca estudou                                       471.658243

# %%
 grafico1 = microdadosenemselecionado.filter(items=['NU_NOTA_MT', 'NO_Q001']).groupby('NO_Q001').mean()

# %%
grafico1.plot()
# Out:
# <AxesSubplot:xlabel='NO_Q001'>

# %%
# Desempenho em Matemática segundo a escolidade do MAE
microdadosenemselecionado.filter(items=['NU_NOTA_MT', 'NO_Q002']).groupby('NO_Q002').mean().sort_values(by='NU_NOTA_MT', ascending=False)
# Out:
#                                                     NU_NOTA_MT
# NO_Q002
# Completou a Pós-graduação                           592.406291
# Completou a Faculdade, mas não completou a Pós-...  582.600755
# Completou o Ensino Médio, mas não completou a F...  533.379838
# Completou a 8ª série/9º ano do Ensino Fundament...  510.363869
# Completou a 4ª série/5º ano, mas não completou ...  501.083591
# Não sei                                             493.232768
# Não completou a 4ª série/5º ano do Ensino Funda...  484.995819
# Nunca estudou                                       464.279863

# %%
# Desempenho em REDAÇÃO do Candidato em relação à escolidade do PAI
microdadosenemselecionado.filter(items=['NU_NOTA_REDACAO', 'NO_Q001']).groupby('NO_Q001').mean().sort_values(by='NU_NOTA_REDACAO')
# Out:
#                                                     NU_NOTA_REDACAO
# NO_Q001
# Nunca estudou                                            533.455935
# Não completou a 4ª série/5º ano do Ensino Funda...       569.846105
# Não sei                                                  574.984766
# Completou a 4ª série/5º ano, mas não completou ...       595.393094
# Completou a 8ª série/9º ano do Ensino Fundament...       609.502341
# Completou o Ensino Médio, mas não completou a F...       636.649891
# Completou a Faculdade, mas não completou a Pós-...       695.124377
# Completou a Pós-graduação                                714.138536

# %%
# Desempenho em Matemática segundo a escolidade do MAE
microdadosenemselecionado.filter(items=['NU_NOTA_REDACAO', 'NO_Q002'])\
.groupby('NO_Q002').mean().sort_values(by='NU_NOTA_REDACAO', ascending=False)
# Out:
#                                                     NU_NOTA_REDACAO
# NO_Q002
# Completou a Pós-graduação                                694.966322
# Completou a Faculdade, mas não completou a Pós-...       679.834240
# Completou o Ensino Médio, mas não completou a F...       624.292778
# Completou a 8ª série/9º ano do Ensino Fundament...       593.212725
# Completou a 4ª série/5º ano, mas não completou ...       579.444599
# Não completou a 4ª série/5º ano do Ensino Funda...       556.906785
# Não sei                                                  538.759712
# Nunca estudou                                            514.674960

# %%
colunasSelecionadas = ['NU_INSCRICAO','NU_NOTA_MT','SG_UF_ESC' 'NU_NOTA_REDACAO','Q001', 'Q002']

# %%
microdadosenemselecionado['SG_UF_ESC'] = microdados_enem.SG_UF_ESC
# Out:
# C:\Users\David\AppData\Local\Temp/ipykernel_5372/3918255951.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   microdadosenemselecionado['SG_UF_ESC'] = microdados_enem.SG_UF_ESC

# %%
microdadosenemselecionado = microdadosenemselecionado.dropna()

# %%
microdadosenemselecionado.head()
# Out:
#     NU_INSCRICAO  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002  \
# 3   210052128335       659.5            780.0    B    B
# 4   210051353021       582.6            780.0    D    E
# 33  210053085526       423.0            700.0    C    C
# 45  210052916275       570.2            640.0    H    E
# 51  210051417174       579.4            680.0    E    F
#
#                                               NO_Q001  \
# 3   Não completou a 4ª série/5º ano do Ensino Fund...
# 4   Completou a 8ª série/9º ano do Ensino Fundamen...
# 33  Completou a 4ª série/5º ano, mas não completou...
# 45                                            Não sei
# 51  Completou o Ensino Médio, mas não completou a ...
#
#                                               NO_Q002 SG_UF_ESC
# 3   Não completou a 4ª série/5º ano do Ensino Fund...        CE
# 4   Completou o Ensino Médio, mas não completou a ...        CE
# 33  Completou a 4ª série/5º ano, mas não completou...        BA
# ...

# %%
microdadosenemselecionado.filter(items=['NU_NOTA_REDACAO', 'NO_Q001'])\
.where(microdadosenemselecionado.SG_UF_ESC == 'MA').groupby('NO_Q001')\
.mean().sort_values(by = 'NU_NOTA_REDACAO', ascending = False)
# Out:
#                                                     NU_NOTA_REDACAO
# NO_Q001
# Completou a Pós-graduação                                708.501742
# Completou a Faculdade, mas não completou a Pós-...       704.372594
# Completou o Ensino Médio, mas não completou a F...       622.508560
# Completou a 8ª série/9º ano do Ensino Fundament...       579.495459
# Completou a 4ª série/5º ano, mas não completou ...       563.651826
# Não sei                                                  562.322581
# Não completou a 4ª série/5º ano do Ensino Funda...       531.726242
# Nunca estudou                                            515.232384

# %%
microdadosenemselecionado.filter(items=['NU_NOTA_REDACAO', 'NO_Q002'])\
.where(microdadosenemselecionado.SG_UF_ESC == 'PI').groupby('NO_Q002')\
.mean().sort_values(by = 'NU_NOTA_REDACAO', ascending = False)
# Out:
#                                                     NU_NOTA_REDACAO
# NO_Q002
# Completou a Pós-graduação                                751.054904
# Completou a Faculdade, mas não completou a Pós-...       725.457831
# Completou o Ensino Médio, mas não completou a F...       657.219873
# Completou a 8ª série/9º ano do Ensino Fundament...       613.601757
# Completou a 4ª série/5º ano, mas não completou ...       575.728329
# Não sei                                                  558.939929
# Não completou a 4ª série/5º ano do Ensino Funda...       553.209773
# Nunca estudou                                            507.630522

# %%
microdadosenemselecionado.filter(items=['SG_UF_ESC','NU_NOTA_REDACAO', 'NO_Q001'])\
.groupby(['SG_UF_ESC','NO_Q001'])\
.mean()
# Out:
#                                                               NU_NOTA_REDACAO
# SG_UF_ESC NO_Q001
# AC        Completou a 4ª série/5º ano, mas não completou ...       582.183406
#           Completou a 8ª série/9º ano do Ensino Fundament...       537.410714
#           Completou a Faculdade, mas não completou a Pós-...       658.357143
#           Completou a Pós-graduação                                694.538153
#           Completou o Ensino Médio, mas não completou a F...       613.311148
# ...                                                                       ...
# TO        Completou a Pós-graduação                                709.617225
#           Completou o Ensino Médio, mas não completou a F...       608.029790
#           Nunca estudou                                            505.102041
#           Não completou a 4ª série/5º ano do Ensino Funda...       517.777778
#           Não sei                                                  541.658031
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
#fig, ax = plt.subplots(figsize = (20,20))
#plt.suptitle('Nota Redação x Escolaridade x Estado')

ax = microdadosenemselecionado.filter(items = ['SG_UF_ESC','NU_NOTA_REDACAO', 'Q002'])\
.groupby(['Q002', 'SG_UF_ESC']).mean().sort_values(by='NU_NOTA_REDACAO', ascending = False)\
.unstack().plot(figsize = (20,7.5), colormap = 'viridis', grid = True)
ax.set_title("Nota Redação x Escolaridade x Estado", fontsize = 20)
#ax.legend(bbox_to_anchor = (1.05, 1), loc= 0, borderaxespad = 0.)

handles, labels = ax.get_legend_handles_labels()

import re
edited_labels = [re.search(',\s(.+?)\)',label).group(1) for label in labels]
ax.legend(edited_labels, bbox_to_anchor = (1.2,1), loc= 0, borderaxespad = 0.)

textdictq002 = " "
for key,value in dicionarioq01q02.items():
    textdictq002 = textdictq002 + "{k} : {v}\n".format(k=key,v=value)
    
ax.text(0.02, 0.75, textdictq002, transform=ax.transAxes, fontsize = 6, color = 'white',
       bbox = {'boxstyle': 'round', 'facecolor': 'black', 'alpha': 0.7})
ax=ax

# %%
#fig, ax = plt.subplots(figsize = (20,20))
#plt.suptitle('Nota Redação x Escolaridade x Estado')

ax = microdadosenemselecionado.filter(items = ['SG_UF_ESC','NU_NOTA_REDACAO', 'Q001'])\
.groupby(['Q001', 'SG_UF_ESC']).mean().sort_values(by='NU_NOTA_REDACAO', ascending = False)\
.unstack().plot(figsize = (20,7.5), colormap = 'viridis', grid = True)
ax.set_title("Nota Redação x Escolaridade x Estado", fontsize = 20)
#ax.legend(bbox_to_anchor = (1.05, 1), loc= 0, borderaxespad = 0.)

handles, labels = ax.get_legend_handles_labels()

import re
edited_labels = [re.search(',\s(.+?)\)',label).group(1) for label in labels]
ax.legend(edited_labels, bbox_to_anchor = (1.2,1), loc= 0, borderaxespad = 0.)

textdictq002 = " "
for key,value in dicionarioq01q02.items():
    textdictq002 = textdictq002 + "{k} : {v}\n".format(k=key,v=value)
    
ax.text(0.02, 0.75, textdictq002, transform=ax.transAxes, fontsize = 6, color = 'white',
       bbox = {'boxstyle': 'round', 'facecolor': 'black', 'alpha': 0.7})
ax=ax

# %%
microdados_enem_selecao = microdados_enem.filter(items=['NO_MUNICIPIO_ESC','SG_UF_ESC','NO_MUNICIPIO_PROVA', 'SG_UF_PROVA','NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
       'NU_NOTA_MT','NU_NOTA_REDACAO'])

# %%
microdados_enem_selecao.head(10)
# Out:
#   NO_MUNICIPIO_ESC SG_UF_ESC     NO_MUNICIPIO_PROVA SG_UF_PROVA  NU_NOTA_CN  \
# 0              NaN       NaN              Nova Lima          MG         NaN
# 1              NaN       NaN                 Maceió          AL       505.9
# 2              NaN       NaN  Ferraz de Vasconcelos          SP         NaN
# 3            Crato        CE                  Crato          CE       580.7
# 4         Redenção        CE                Acarape          CE       497.7
# 5              NaN       NaN               Cascavel          CE         NaN
# 6              NaN       NaN              Tramandaí          RS         NaN
# 7              NaN       NaN                  Matão          SP         NaN
# 8              NaN       NaN         Belo Horizonte          MG       487.4
# 9              NaN       NaN            Ruy Barbosa          BA       507.6
#
#    NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO
# 0       574.6       472.6         NaN            760.0
# ...

# %% [markdown]
# Explorar as media das notas por municipio

# %%
mediaenem_municipio = microdados_enem_selecao.groupby(['NO_MUNICIPIO_PROVA',
       'SG_UF_ESC'], as_index=False).mean()
mediaenem_municipio.head()
# Out:
#   NO_MUNICIPIO_PROVA SG_UF_ESC  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  \
# 0         Abaetetuba        MG  455.300000  384.300000  374.800000
# 1         Abaetetuba        PA  465.102809  479.955935  459.888489
# 2             Abaeté        MG  497.460577  525.605607  508.243925
# 3             Abaeté        SP         NaN         NaN         NaN
# 4       Abreu e Lima        PE  467.448903  485.006287  476.178443
#
#    NU_NOTA_MT  NU_NOTA_REDACAO
# 0  383.300000       480.000000
# 1  486.351873       595.611511
# 2  552.215385       627.476636
# 3         NaN              NaN
# 4  496.851411       558.143713

# %%
max_notas_municipio = microdados_enem_selecao.groupby(['NO_MUNICIPIO_PROVA',
       'SG_UF_PROVA'], as_index=False).max()
# Out:
# C:\Users\David\AppData\Local\Temp/ipykernel_5372/3208899181.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   max_notas_municipio = microdados_enem_selecao.groupby(['NO_MUNICIPIO_PROVA',

# %%
max_notas_municipio.query('NO_MUNICIPIO_PROVA == "Caxias"')
# Out:
#     NO_MUNICIPIO_PROVA SG_UF_PROVA  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  \
# 410             Caxias          MA       743.0       782.7       752.7
#
#      NU_NOTA_MT  NU_NOTA_REDACAO
# 410       882.7            980.0

# %%
max_notas_municipio.query('NO_MUNICIPIO_PROVA == "Pedreiras"')
# Out:
#      NO_MUNICIPIO_PROVA SG_UF_PROVA  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  \
# 1172          Pedreiras          MA       736.7       770.8       759.6
#
#       NU_NOTA_MT  NU_NOTA_REDACAO
# 1172       832.4            960.0

# %%
mediaenem_municipio.query('SG_UF_ESC == "MA" & NO_MUNICIPIO_PROVA == "Pedreiras"')
# Out:
#      NO_MUNICIPIO_PROVA SG_UF_ESC  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  \
# 2853          Pedreiras        MA  458.655435  483.467347  473.790476
#
#       NU_NOTA_MT  NU_NOTA_REDACAO
# 2853  495.305072       618.639456

# %%
mediaenem_municipio.query('SG_UF_ESC == "MA" & NO_MUNICIPIO_PROVA == "Caxias"')
# Out:
#      NO_MUNICIPIO_PROVA SG_UF_ESC  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  \
# 1028             Caxias        MA  463.634186  476.098936  463.005319
#
#       NU_NOTA_MT  NU_NOTA_REDACAO
# 1028  482.596161       574.929078

# %%
mediaenem_municipio.query('SG_UF_ESC == "PI" & NO_MUNICIPIO_PROVA == "Teresina"')
# Out:
#      NO_MUNICIPIO_PROVA SG_UF_ESC  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  \
# 3968           Teresina        PI  507.825812  535.014286  516.917726
#
#       NU_NOTA_MT  NU_NOTA_REDACAO
# 3968  565.570427       699.638502

# %%
mediaenem_municipio.query('SG_UF_ESC == "CE" & NO_MUNICIPIO_PROVA == "Fortaleza"')
# Out:
#      NO_MUNICIPIO_PROVA SG_UF_ESC  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  \
# 1462          Fortaleza        CE   481.51602  508.937649  493.964778
#
#       NU_NOTA_MT  NU_NOTA_REDACAO
# 1462   530.12128       595.931235

# %% [markdown]
# EXPORTAR UM ARQUIVO CSV COMO OUTRO DATAFRAME

# %%
mediaenem_municipio.to_csv('mediaenem_municipio.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py:2074: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)

# %%
mediaenem_municipio.head()
# Out:
#   NO_MUNICIPIO_PROVA SG_UF_ESC  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  \
# 0         Abaetetuba        MG  455.300000  384.300000  374.800000
# 1         Abaetetuba        PA  465.102809  479.955935  459.888489
# 2             Abaeté        MG  497.460577  525.605607  508.243925
# 3             Abaeté        SP         NaN         NaN         NaN
# 4       Abreu e Lima        PE  467.448903  485.006287  476.178443
#
#    NU_NOTA_MT  NU_NOTA_REDACAO
# 0  383.300000       480.000000
# 1  486.351873       595.611511
# 2  552.215385       627.476636
# 3         NaN              NaN
# 4  496.851411       558.143713

# %% [markdown]
# AGLUTINAR DOIS CONJUNTOS DE DADOS

# %%
atlashumano = pd.read_csv('AtlasHumano.csv', sep=';')

# %%
atlashumano.columns.values
# Out:
# array(['ANO', 'UF', 'Codmun6', 'Codmun7', 'IDHM', 'IDHM_E', 'IDHM_L',
#        'IDHM_R'], dtype=object)

# %%
atlashumano.sample(50)
# Out:
#        ANO  UF  Codmun6  Codmun7   IDHM IDHM_E IDHM_L IDHM_R
# 2309  2010  31   310630  3106309  0,686  0,606  0,813  0,655
# 249   2010  15   150611  1506112  0,543  0,397  0,732   0,55
# 476   2010  21   210173  2101731  0,512  0,455  0,707  0,417
# 5136  2010  50   500430  5004304  0,662   0,53  0,817  0,671
# 3688  2010  35   353750  3537503  0,736  0,637  0,873  0,717
# 4493  2010  42   421210  4212106  0,737  0,632  0,836  0,757
# 3736  2010  35   354190  3541901  0,722  0,687  0,823  0,665
# 2642  2010  31   313530  3135308  0,721  0,656  0,844  0,677
# 5535  2010  52   522010  5220108  0,731   0,67  0,809  0,721
# 1187  2010  24   241040  2410405  0,567  0,456  0,774  0,516
# 3784  2010  35   354630  3546306  0,728  0,635  0,815  0,746
# 2674  2010  31   313770  3137700  0,661  0,541   0,81  0,659
# 1677  2010  27   270260  2702603  0,533  0,402  0,736  0,512
# 5430  2010  52   521020  5210208  0,743  0,667   0,84  0,731
# ...

# %%
mediaenem_idhm = pd.merge(mediaenem_municipio, atlashumano, how='left', left_on=['CO_MUNICIPIO_ESC'], right_on=['Codmun7'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5372/1475892172.py in <module>
# ----> 1 mediaEnem_idhm = pd.merge(mediaenem_municipio, atlashumano, how='left', left_on=['CO_MUNICIPIO_ESC'], right_on=['Codmun7'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
#     108         right,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     697             self.right_join_keys,
#     698             self.join_names,
# ...

# %%
mediaEnem_idhm

# %%
mediaEnem_idhm.dtypes

# %%
mediaEnem_idhm['IDHM'] = mediaEnem_idhm['IDHM'].apply(lambda x:str(x).replace(',','.'))
mediaEnem_idhm['IDHM_R'] = mediaEnem_idhm['IDHM_R'].apply(lambda x:str(x).replace(',','.'))
mediaEnem_idhm['IDHM_E'] = mediaEnem_idhm['IDHM_E'].apply(lambda x:str(x).replace(',','.'))
mediaEnem_idhm['IDHM_L'] = mediaEnem_idhm['IDHM_L'].apply(lambda x:str(x).replace(',','.'))

# %%
mediaEnem_idhm['IDHM']

# %%
mediaEnem_idhm.plot.scatter('CO_PROVA_MT','IDHM',figsize = (20,20))
